# %% [markdown]
# ## API Requests - Weekly

# %% [markdown]
# ### Imports

# %%
import requests
import json
from dotenv import load_dotenv
import os
import pandas as pd

# %% [markdown]
# ### Declare Stock Symbol

# %%
stockName = 'JNJ'

# %% [markdown]
# ### Fetching AlphaVantage API Key

# %%
# Load .env file variables
load_dotenv()

# Access the API key
api_key = os.getenv('alphaKey')

# %% [markdown]
# ### Send Request to AlphaVantage API

# %%
# Use the API key in the URL
url = f"https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY_ADJUSTED&symbol={stockName}&apikey={api_key}"
response = requests.get(url)
data = response.json()

# %%
data
# Out:
# {'Meta Data': {'1. Information': 'Weekly Adjusted Prices and Volumes',
#   '2. Symbol': 'JNJ',
#   '3. Last Refreshed': '2024-04-22',
#   '4. Time Zone': 'US/Eastern'},
#  'Weekly Adjusted Time Series': {'2024-04-22': {'1. open': '148.5100',
#    '2. high': '150.2700',
#    '3. low': '147.3000',
#    '4. close': '149.1200',
#    '5. adjusted close': '149.1200',
#    '6. volume': '10118694',
#    '7. dividend amount': '0.0000'},
#   '2024-04-19': {'1. open': '148.3700',
#    '2. high': '149.4900',
#    '3. low': '143.1300',
#    '4. close': '147.9100',
#    '5. adjusted close': '147.9100',
#    '6. volume': '50293639',
#    '7. dividend amount': '0.0000'},
#   '2024-04-12': {'1. open': '151.9900',
#    '2. high': '153.0350',
#    '3. low': '147.1500',
#    '4. close': '147.5200',
#    '5. adjusted close': '147.5200',
#    '6. volume': '34293828',
#    '7. dividend amount': '0.0000'},
#   '2024-04-05': {'1. open': '157.7200',
#    '2. high': '158.1500',
#    '3. low': '151.6100',
#    '4. close': '152.3900',
#    '5. adjusted close': '152.3900',
#    '6. volume': '31591782',
#    '7. dividend amount': '0.0000'},
#   '2024-03-28': {'1. open': '155.4000',
#    '2. high': '159.1400',
#    '3. low': '154.7600',
#    '4. close': '158.1900',
#    '5. adjusted close': '158.1900',
#    '6. volume': '29005302',
#    '7. dividend amount': '0.0000'},
#   '2024-03-22': {'1. open': '158.5700',
#    '2. high': '158.6900',
#    '3. low': '155.1000',
#    '4. close': '155.2300',
#    '5. adjusted close': '155.2300',
#    '6. volume': '33589582',
#    '7. dividend amount': '0.0000'},
#   '2024-03-15': {'1. open': '159.4900',
#    '2. high': '163.1100',
#    '3. low': '157.1000',
#    '4. close': '158.1800',
#    '5. adjusted close': '158.1800',
#    '6. volume': '38913177',
#    '7. dividend amount': '0.0000'},
#   '2024-03-08': {'1. open': '161.3200',
#    '2. high': '161.6100',
#    '3. low': '158.2400',
#    '4. close': '159.5200',
#    '5. adjusted close': '159.5200',
#    '6. volume': '33077625',
#    '7. dividend amount': '0.0000'},
#   '2024-03-01': {'1. open': '161.8000',
#    '2. high': '162.5700',
#    '3. low': '159.6400',
#    '4. close': '162.1200',
#    '5. adjusted close': '162.1200',
#    '6. volume': '32134548',
#    '7. dividend amount': '0.0000'},
#   '2024-02-23': {'1. open': '156.5600',
#    '2. high': '162.2500',
#    '3. low': '156.4400',
#    '4. close': '161.8400',
#    '5. adjusted close': '161.8400',
#    '6. volume': '31766015',
#    '7. dividend amount': '0.0000'},
#   '2024-02-16': {'1. open': '156.5800',
#    '2. high': '158.4750',
#    '3. low': '154.8400',
#    '4. close': '156.5500',
#    '5. adjusted close': '156.5500',
#    '6. volume': '40424825',
#    '7. dividend amount': '1.1900'},
#   '2024-02-09': {'1. open': '156.6100',
#    '2. high': '159.3700',
#    '3. low': '155.3100',
#    '4. close': '156.7600',
#    '5. adjusted close': '155.5774',
#    '6. volume': '43326875',
#    '7. dividend amount': '0.0000'},
#   '2024-02-02': {'1. open': '159.0100',
#    '2. high': '160.6200',
#    '3. low': '155.9400',
#    '4. close': '156.6100',
#    '5. adjusted close': '155.4285',
#    '6. volume': '38248795',
#    '7. dividend amount': '0.0000'},
#   '2024-01-26': {'1. open': '162.0000',
#    '2. high': '163.5800',
#    '3. low': '156.9100',
#    '4. close': '159.5000',
#    '5. adjusted close': '158.2967',
#    '6. volume': '33631034',
#    '7. dividend amount': '0.0000'},
#   '2024-01-19': {'1. open': '161.5700',
#    '2. high': '162.2500',
#    '3. low': '159.6900',
#    '4. close': '161.6800',
#    '5. adjusted close': '160.4603',
#    '6. volume': '24435100',
#    '7. dividend amount': '0.0000'},
#   '2024-01-12': {'1. open': '161.1000',
#    '2. high': '163.2800',
#    '3. low': '159.6100',
#    '4. close': '162.3900',
#    '5. adjusted close': '161.1649',
#    '6. volume': '27314869',
#    '7. dividend amount': '0.0000'},
#   '2024-01-05': {'1. open': '156.9300',
#    '2. high': '161.9800',
#    '3. low': '156.7900',
#    '4. close': '161.1300',
#    '5. adjusted close': '159.9144',
#    '6. volume': '29721775',
#    '7. dividend amount': '0.0000'},
#   '2023-12-29': {'1. open': '155.0000',
#    '2. high': '157.2400',
#    '3. low': '154.8500',
#    '4. close': '156.7400',
#    '5. adjusted close': '155.5575',
#    '6. volume': '18095197',
#    '7. dividend amount': '0.0000'},
#   '2023-12-22': {'1. open': '155.2100',
#    '2. high': '156.6600',
#    '3. low': '153.1100',
#    '4. close': '155.4600',
#    '5. adjusted close': '154.2872',
#    '6. volume': '29076489',
#    '7. dividend amount': '0.0000'},
#   '2023-12-15': {'1. open': '154.5000',
#    '2. high': '157.1600',
#    '3. low': '151.7700',
#    '4. close': '155.1600',
#    '5. adjusted close': '153.9895',
#    '6. volume': '53147895',
#    '7. dividend amount': '0.0000'},
#   '2023-12-08': {'1. open': '158.0000',
#    '2. high': '160.0200',
#    '3. low': '153.8400',
#    '4. close': '154.4200',
#    '5. adjusted close': '153.2550',
#    '6. volume': '35527758',
#    '7. dividend amount': '0.0000'},
#   '2023-12-01': {'1. open': '152.2900',
#    '2. high': '158.4600',
#    '3. low': '150.8400',
#    '4. close': '158.3800',
#    '5. adjusted close': '157.1852',
#    '6. volume': '40373578',
#    '7. dividend amount': '0.0000'},
#   '2023-11-24': {'1. open': '147.9100',
#    '2. high': '152.6794',
#    '3. low': '147.5400',
#    '4. close': '152.5000',
#    '5. adjusted close': '151.3495',
#    '6. volume': '22763767',
#    '7. dividend amount': '1.1900'},
#   '2023-11-17': {'1. open': '147.2500',
#    '2. high': '150.7850',
#    '3. low': '146.6500',
#    '4. close': '149.7900',
#    '5. adjusted close': '147.4892',
#    '6. volume': '33233244',
#    '7. dividend amount': '0.0000'},
#   '2023-11-10': {'1. open': '151.7800',
#    '2. high': '152.4250',
#    '3. low': '145.6400',
#    '4. close': '147.2500',
#    '5. adjusted close': '144.9882',
#    '6. volume': '29057387',
#    '7. dividend amount': '0.0000'},
#   '2023-11-03': {'1. open': '146.0900',
#    '2. high': '152.2700',
#    '3. low': '146.0000',
#    '4. close': '151.3400',
#    '5. adjusted close': '149.0154',
#    '6. volume': '31791361',
#    '7. dividend amount': '0.0000'},
#   '2023-10-27': {'1. open': '152.8600',
#    '2. high': '153.5000',
#    '3. low': '144.9500',
#    '4. close': '145.6000',
#    '5. adjusted close': '143.3636',
#    '6. volume': '36908324',
#    '7. dividend amount': '0.0000'},
#   '2023-10-20': {'1. open': '157.8200',
#    '2. high': '158.9499',
#    '3. low': '150.1500',
#    '4. close': '153.0000',
#    '5. adjusted close': '150.6499',
#    '6. volume': '42690630',
#    '7. dividend amount': '0.0000'},
#   '2023-10-13': {'1. open': '157.1800',
#    '2. high': '159.2700',
#    '3. low': '155.0663',
#    '4. close': '156.8500',
#    '5. adjusted close': '154.4407',
#    '6. volume': '27763526',
#    '7. dividend amount': '0.0000'},
#   '2023-10-06': {'1. open': '155.4200',
#    '2. high': '158.3000',
#    '3. low': '153.3200',
#    '4. close': '157.6400',
#    '5. adjusted close': '155.2186',
#    '6. volume': '29752045',
#    '7. dividend amount': '0.0000'},
#   '2023-09-29': {'1. open': '160.0700',
#    '2. high': '160.3600',
#    '3. low': '155.2550',
#    '4. close': '155.7500',
#    '5. adjusted close': '153.3576',
#    '6. volume': '37380720',
#    '7. dividend amount': '0.0000'},
#   '2023-09-22': {'1. open': '162.1200',
#    '2. high': '163.5354',
#    '3. low': '160.2500',
#    '4. close': '160.5000',
#    '5. adjusted close': '158.0347',
#    '6. volume': '24681718',
#    '7. dividend amount': '0.0000'},
#   '2023-09-15': {'1. open': '161.0600',
#    '2. high': '165.2700',
#    '3. low': '160.4500',
#    '4. close': '161.4500',
#    '5. adjusted close': '158.9701',
#    '6. volume': '40903197',
#    '7. dividend amount': '0.0000'},
#   '2023-09-08': {'1. open': '160.5600',
#    '2. high': '161.9700',
#    '3. low': '157.3500',
#    '4. close': '160.5600',
#    '5. adjusted close': '158.0938',
#    '6. volume': '35663622',
#    '7. dividend amount': '0.0000'},
#   '2023-09-01': {'1. open': '165.0000',
#    '2. high': '166.2100',
#    '3. low': '160.0150',
#    '4. close': '160.4800',
#    '5. adjusted close': '158.0150',
#    '6. volume': '64548753',
#    '7. dividend amount': '0.0000'},
#   '2023-08-25': {'1. open': '169.6900',
#    '2. high': '169.8500',
#    '3. low': '163.4700',
#    '4. close': '166.2500',
#    '5. adjusted close': '163.6964',
#    '6. volume': '416106868',
#    '7. dividend amount': '1.1900'},
#   '2023-08-18': {'1. open': '173.5200',
#    '2. high': '175.6000',
#    '3. low': '171.3100',
#    '4. close': '172.4900',
#    '5. adjusted close': '168.6335',
#    '6. volume': '359092083',
#    '7. dividend amount': '0.0000'},
#   '2023-08-11': {'1. open': '169.4900',
#    '2. high': '175.9700',
#    '3. low': '169.3600',
#    '4. close': '173.8500',
#    '5. adjusted close': '169.9630',
#    '6. volume': '182208969',
#    '7. dividend amount': '0.0000'},
#   '2023-08-04': {'1. open': '169.6900',
#    '2. high': '172.6800',
#    '3. low': '166.0600',
#    '4. close': '169.0400',
#    '5. adjusted close': '165.2606',
#    '6. volume': '93883812',
#    '7. dividend amount': '0.0000'},
#   '2023-07-28': {'1. open': '171.5000',
#    '2. high': '175.3600',
#    '3. low': '169.7500',
#    '4. close': '174.4800',
#    '5. adjusted close': '170.5790',
#    '6. volume': '69818897',
#    '7. dividend amount': '0.0000'},
#   '2023-07-21': {'1. open': '159.7500',
#    '2. high': '170.8200',
#    '3. low': '157.3300',
#    '4. close': '170.1900',
#    '5. adjusted close': '166.3849',
#    '6. volume': '53315976',
#    '7. dividend amount': '0.0000'},
#   '2023-07-14': {'1. open': '159.4300',
#    '2. high': '160.3000',
#    '3. low': '157.4100',
#    '4. close': '159.8700',
#    '5. adjusted close': '156.2956',
#    '6. volume': '31050742',
#    '7. dividend amount': '0.0000'},
#   '2023-07-07': {'1. open': '164.3400',
#    '2. high': '164.3900',
#    '3. low': '159.2000',
#    '4. close': '159.2500',
#    '5. adjusted close': '155.6895',
#    '6. volume': '24615149',
#    '7. dividend amount': '0.0000'},
#   '2023-06-30': {'1. open': '164.9800',
#    '2. high': '165.9400',
#    '3. low': '161.3300',
#    '4. close': '165.5200',
#    '5. adjusted close': '161.8193',
#    '6. volume': '30814605',
#    '7. dividend amount': '0.0000'},
#   '2023-06-23': {'1. open': '164.2600',
#    '2. high': '166.2700',
#    '3. low': '162.6900',
#    '4. close': '165.4800',
#    '5. adjusted close': '161.7802',
#    '6. volume': '30110576',
#    '7. dividend amount': '0.0000'},
#   '2023-06-16': {'1. open': '160.0000',
#    '2. high': '164.9900',
#    '3. low': '158.7300',
#    '4. close': '164.2300',
#    '5. adjusted close': '160.5581',
#    '6. volume': '39842108',
#    '7. dividend amount': '0.0000'},
#   '2023-06-09': {'1. open': '156.7500',
#    '2. high': '160.7250',
#    '3. low': '156.7500',
#    '4. close': '160.0100',
#    '5. adjusted close': '156.4325',
#    '6. volume': '30092158',
#    '7. dividend amount': '0.0000'},
#   '2023-06-02': {'1. open': '153.9700',
#    '2. high': '157.3100',
#    '3. low': '153.1500',
#    '4. close': '156.9700',
#    '5. adjusted close': '153.4605',
#    '6. volume': '31752843',
#    '7. dividend amount': '0.0000'},
#   '2023-05-26': {'1. open': '158.0000',
#    '2. high': '159.1400',
#    '3. low': '153.7200',
#    '4. close': '154.3500',
#    '5. adjusted close': '150.8990',
#    '6. volume': '30215536',
#    '7. dividend amount': '1.1900'},
#   '2023-05-19': {'1. open': '160.8000',
#    '2. high': '161.0300',
#    '3. low': '157.5600',
#    '4. close': '158.9100',
#    '5. adjusted close': '154.1874',
#    '6. volume': '29244785',
#    '7. dividend amount': '0.0000'},
#   '2023-05-12': {'1. open': '161.9900',
#    '2. high': '162.5700',
#    '3. low': '159.3901',
#    '4. close': '160.7800',
#    '5. adjusted close': '156.0019',
#    '6. volume': '27044147',
#    '7. dividend amount': '0.0000'},
#   '2023-05-05': {'1. open': '163.6000',
#    '2. high': '166.1800',
#    '3. low': '161.2500',
#    '4. close': '162.6800',
#    '5. adjusted close': '157.8454',
#    '6. volume': '28694773',
#    '7. dividend amount': '0.0000'},
#   '2023-04-28': {'1. open': '162.6900',
#    '2. high': '165.3500',
#    '3. low': '161.8700',
#    '4. close': '163.7000',
#    '5. adjusted close': '158.8351',
#    '6. volume': '28749211',
#    '7. dividend amount': '0.0000'},
#   '2023-04-21': {'1. open': '165.7350',
#    '2. high': '166.2400',
#    '3. low': '159.6500',
#    '4. close': '162.6900',
#    '5. adjusted close': '157.8551',
#    '6. volume': '45871357',
#    '7. dividend amount': '0.0000'},
#   '2023-04-14': {'1. open': '164.6300',
#    '2. high': '166.3300',
#    '3. low': '163.1000',
#    '4. close': '165.8400',
#    '5. adjusted close': '160.9115',
#    '6. volume': '29887759',
#    '7. dividend amount': '0.0000'},
#   '2023-04-06': {'1. open': '154.9500',
#    '2. high': '167.2300',
#    '3. low': '153.9400',
#    '4. close': '165.1500',
#    '5. adjusted close': '160.2420',
#    '6. volume': '41476003',
#    '7. dividend amount': '0.0000'},
#   '2023-03-31': {'1. open': '154.2000',
#    '2. high': '155.1900',
#    '3. low': '151.7250',
#    '4. close': '155.0000',
#    '5. adjusted close': '150.3936',
#    '6. volume': '33345557',
#    '7. dividend amount': '0.0000'},
#   '2023-03-24': {'1. open': '152.4700',
#    '2. high': '154.1300',
#    '3. low': '150.1100',
#    '4. close': '152.6500',
#    '5. adjusted close': '148.1135',
#    '6. volume': '38197682',
#    '7. dividend amount': '0.0000'},
#   '2023-03-17': {'1. open': '152.0900',
#    '2. high': '155.9100',
#    '3. low': '151.5700',
#    '4. close': '152.3800',
#    '5. adjusted close': '147.8515',
#    '6. volume': '55125197',
#    '7. dividend amount': '0.0000'},
#   '2023-03-10': {'1. open': '154.6600',
#    '2. high': '156.2500',
#    '3. low': '150.7100',
#    '4. close': '151.6100',
#    '5. adjusted close': '147.1044',
#    '6. volume': '37780143',
#    '7. dividend amount': '0.0000'},
#   '2023-03-03': {'1. open': '156.4500',
#    '2. high': '156.9000',
#    '3. low': '151.2310',
#    '4. close': '154.0200',
#    '5. adjusted close': '149.4428',
#    '6. volume': '37608664',
#    '7. dividend amount': '0.0000'},
#   '2023-02-24': {'1. open': '159.6500',
#    '2. high': '160.3500',
#    '3. low': '155.2100',
#    '4. close': '155.9700',
#    '5. adjusted close': '151.3348',
#    '6. volume': '37318918',
#    '7. dividend amount': '0.0000'},
#   '2023-02-17': {'1. open': '161.3300',
#    '2. high': '162.9699',
#    '3. low': '156.6200',
#    '4. close': '160.3900',
#    '5. adjusted close': '155.6234',
#    '6. volume': '48942905',
#    '7. dividend amount': '1.1300'},
#   '2023-02-10': {'1. open': '164.5500',
#    '2. high': '164.8525',
#    '3. low': '161.0700',
#    '4. close': '162.1500',
#    '5. adjusted close': '156.2304',
#    '6. volume': '35364025',
#    '7. dividend amount': '0.0000'},
#   '2023-02-03': {'1. open': '167.9300',
#    '2. high': '168.5400',
#    '3. low': '161.0500',
#    '4. close': '164.6100',
#    '5. adjusted close': '158.6006',
#    '6. volume': '61704404',
#    '7. dividend amount': '0.0000'},
#   '2023-01-27': {'1. open': '169.1000',
#    '2. high': '175.0000',
#    '3. low': '166.0100',
#    '4. close': '168.2300',
#    '5. adjusted close': '162.0885',
#    '6. volume': '39071280',
#    '7. dividend amount': '0.0000'},
#   '2023-01-20': {'1. open': '174.0000',
#    '2. high': '174.5800',
#    '3. low': '167.4800',
#    '4. close': '168.7400',
#    '5. adjusted close': '162.5799',
#    '6. volume': '28661128',
#    '7. dividend amount': '0.0000'},
#   '2023-01-13': {'1. open': '179.3000',
#    '2. high': '179.7600',
#    '3. low': '172.1100',
#    '4. close': '173.4300',
#    '5. adjusted close': '167.0986',
#    '6. volume': '29825048',
#    '7. dividend amount': '0.0000'},
#   '2023-01-06': {'1. open': '176.1600',
#    '2. high': '180.9300',
#    '3. low': '176.0100',
#    '4. close': '180.2500',
#    '5. adjusted close': '173.6697',
#    '6. volume': '28094916',
#    '7. dividend amount': '0.0000'},
#   '2022-12-30': {'1. open': '178.1100',
#    '2. high': '178.4500',
#    '3. low': '175.4000',
#    '4. close': '176.6500',
#    '5. adjusted close': '170.2011',
#    '6. volume': '12758347',
#    '7. dividend amount': '0.0000'},
#   '2022-12-23': {'1. open': '175.3500',
#    '2. high': '178.1800',
#    '3. low': '174.0700',
#    '4. close': '177.4800',
#    '5. adjusted close': '171.0008',
#    '6. volume': '26775477',
#    '7. dividend amount': '0.0000'},
#   '2022-12-16': {'1. open': '175.9500',
#    '2. high': '181.0390',
#    '3. low': '174.8600',
#    '4. close': '175.6700',
#    '5. adjusted close': '169.2569',
#    '6. volume': '50037983',
#    '7. dividend amount': '0.0000'},
#   '2022-12-09': {'1. open': '178.3600',
#    '2. high': '180.0000',
#    '3. low': '175.6600',
#    '4. close': '175.7400',
#    '5. adjusted close': '169.3243',
#    '6. volume': '28126164',
#    '7. dividend amount': '0.0000'},
#   '2022-12-02': {'1. open': '176.7500',
#    '2. high': '179.9600',
#    '3. low': '174.6600',
#    '4. close': '178.8800',
#    '5. adjusted close': '172.3497',
#    '6. volume': '38278276',
#    '7. dividend amount': '0.0000'},
#   '2022-11-25': {'1. open': '175.8900',
#    '2. high': '178.1200',
#    '3. low': '174.8300',
#    '4. close': '177.2400',
#    '5. adjusted close': '170.7696',
#    '6. volume': '18862676',
#    '7. dividend amount': '1.1300'},
#   '2022-11-18': {'1. open': '170.2500',
#    '2. high': '176.6400',
#    '3. low': '170.2500',
#    '4. close': '176.2000',
#    '5. adjusted close': '168.6843',
#    '6. volume': '32455013',
#    '7. dividend amount': '0.0000'},
#   '2022-11-11': {'1. open': '171.6700',
#    '2. high': '175.0000',
#    '3. low': '166.8200',
#    '4. close': '169.2500',
#    '5. adjusted close': '162.0308',
#    '6. volume': '36871823',
#    '7. dividend amount': '0.0000'},
#   '2022-11-04': {'1. open': '174.5200',
#    '2. high': '175.1600',
#    '3. low': '168.9400',
#    '4. close': '171.4800',
#    '5. adjusted close': '164.1656',
#    '6. volume': '31794203',
#    '7. dividend amount': '0.0000'},
#   '2022-10-28': {'1. open': '169.8100',
#    '2. high': '175.3900',
#    '3. low': '168.5200',
#    '4. close': '174.8700',
#    '5. adjusted close': '167.4110',
#    '6. volume': '30106568',
#    '7. dividend amount': '0.0000'},
#   '2022-10-21': {'1. open': '165.4000',
#    '2. high': '169.3700',
#    '3. low': '163.0500',
#    '4. close': '168.7100',
#    '5. adjusted close': '161.5138',
#    '6. volume': '41786515',
#    '7. dividend amount': '0.0000'},
#   '2022-10-14': {'1. open': '160.6300',
#    '2. high': '165.9900',
#    '3. low': '159.1800',
#    '4. close': '164.4600',
#    '5. adjusted close': '157.4451',
#    '6. volume': '28019746',
#    '7. dividend amount': '0.0000'},
#   '2022-10-07': {'1. open': '164.2900',
#    '2. high': '166.0400',
#    '3. low': '159.1700',
#    '4. close': '160.2000',
#    '5. adjusted close': '153.3668',
#    '6. volume': '31686859',
#    '7. dividend amount': '0.0000'},
#   '2022-09-30': {'1. open': '165.8000',
#    '2. high': '167.6700',
#    '3. low': '163.3200',
#    '4. close': '163.3600',
#    '5. adjusted close': '156.3920',
#    '6. volume': '42076673',
#    '7. dividend amount': '0.0000'},
#   '2022-09-23': {'1. open': '166.3000',
#    '2. high': '167.4800',
#    '3. low': '162.8300',
#    '4. close': '166.7200',
#    '5. adjusted close': '159.6087',
#    '6. volume': '39522861',
#    '7. dividend amount': '0.0000'},
#   '2022-09-16': {'1. open': '166.1100',
#    '2. high': '167.6300',
#    '3. low': '160.8100',
#    '4. close': '167.6000',
#    '5. adjusted close': '160.4511',
#    '6. volume': '50023397',
#    '7. dividend amount': '0.0000'},
#   '2022-09-09': {'1. open': '163.9400',
#    '2. high': '166.2150',
#    '3. low': '162.1600',
#    '4. close': '165.7100',
#    '5. adjusted close': '158.6418',
#    '6. volume': '23272165',
#    '7. dividend amount': '0.0000'},
#   '2022-09-02': {'1. open': '163.4700',
#    '2. high': '166.2000',
#    '3. low': '161.2700',
#    '4. close': '162.7400',
#    '5. adjusted close': '155.7984',
#    '6. volume': '34220478',
#    '7. dividend amount': '0.0000'},
#   '2022-08-26': {'1. open': '168.9000',
#    '2. high': '168.9200',
#    '3. low': '164.1950',
#    '4. close': '164.2700',
#    '5. adjusted close': '157.2632',
#    '6. volume': '28058973',
#    '7. dividend amount': '1.1300'},
#   '2022-08-19': {'1. open': '166.0000',
#    '2. high': '170.1200',
#    '3. low': '165.1250',
#    '4. close': '169.3100',
#    '5. adjusted close': '161.0026',
#    '6. volume': '41372877',
#    '7. dividend amount': '0.0000'},
#   '2022-08-12': {'1. open': '171.3000',
#    '2. high': '171.4800',
#    '3. low': '165.1500',
#    '4. close': '165.3000',
#    '5. adjusted close': '157.1894',
#    '6. volume': '39702395',
#    '7. dividend amount': '0.0000'},
#   '2022-08-05': {'1. open': '174.1700',
#    '2. high': '175.4900',
#    '3. low': '169.7900',
#    '4. close': '171.1100',
#    '5. adjusted close': '162.7143',
#    '6. volume': '27152634',
#    '7. dividend amount': '0.0000'},
#   '2022-07-29': {'1. open': '172.1200',
#    '2. high': '176.0900',
#    '3. low': '171.1300',
#    '4. close': '174.5200',
#    '5. adjusted close': '165.9570',
#    '6. volume': '25575763',
#    '7. dividend amount': '0.0000'},
#   '2022-07-22': {'1. open': '177.7400',
#    '2. high': '178.1900',
#    '3. low': '169.7600',
#    '4. close': '172.1200',
#    '5. adjusted close': '163.6747',
#    '6. volume': '38304143',
#    '7. dividend amount': '0.0000'},
#   '2022-07-15': {'1. open': '177.7000',
#    '2. high': '179.0200',
#    '3. low': '172.2968',
#    '4. close': '178.2300',
#    '5. adjusted close': '169.4849',
#    '6. volume': '24696683',
#    '7. dividend amount': '0.0000'},
#   '2022-07-08': {'1. open': '178.8300',
#    '2. high': '179.9900',
#    '3. low': '174.6100',
#    '4. close': '178.2800',
#    '5. adjusted close': '169.5325',
#    '6. volume': '20567208',
#    '7. dividend amount': '0.0000'},
#   '2022-07-01': {'1. open': '181.6400',
#    '2. high': '183.3506',
#    '3. low': '175.0300',
#    '4. close': '179.5200',
#    '5. adjusted close': '170.7117',
#    '6. volume': '38559563',
#    '7. dividend amount': '0.0000'},
#   '2022-06-24': {'1. open': '170.7500',
#    '2. high': '182.5300',
#    '3. low': '169.5600',
#    '4. close': '182.2900',
#    '5. adjusted close': '173.3457',
#    '6. volume': '38411015',
#    '7. dividend amount': '0.0000'},
#   '2022-06-17': {'1. open': '170.0800',
#    '2. high': '172.2500',
#    '3. low': '167.2600',
#    '4. close': '169.4600',
#    '5. adjusted close': '161.1453',
#    '6. volume': '42453441',
#    '7. dividend amount': '0.0000'},
#   '2022-06-10': {'1. open': '177.2100',
#    '2. high': '179.4500',
#    '3. low': '170.6212',
#    '4. close': '172.5500',
#    '5. adjusted close': '164.0836',
#    '6. volume': '27325708',
#    '7. dividend amount': '0.0000'},
#   '2022-06-03': {'1. open': '178.0000',
#    '2. high': '180.1700',
#    '3. low': '174.5884',
#    '4. close': '176.4200',
#    '5. adjusted close': '167.7638',
#    '6. volume': '34467581',
#    '7. dividend amount': '0.0000'},
#   '2022-05-27': {'1. open': '177.6000',
#    '2. high': '181.7400',
#    '3. low': '177.4600',
#    '4. close': '181.0900',
#    '5. adjusted close': '172.2046',
#    '6. volume': '32771029',
#    '7. dividend amount': '1.1300'},
#   '2022-05-20': {'1. open': '176.8500',
#    '2. high': '179.7000',
#    '3. low': '172.6900',
#    '4. close': '176.9800',
#    '5. adjusted close': '167.2431',
#    '6. volume': '34273237',
#    '7. dividend amount': '0.0000'},
#   '2022-05-13': {'1. open': '175.4500',
#    '2. high': '179.1800',
#    '3. low': '174.5900',
#    '4. close': '176.8500',
#    '5. adjusted close': '167.1202',
#    '6. volume': '36811553',
#    '7. dividend amount': '0.0000'},
#   '2022-05-06': {'1. open': '180.4700',
#    '2. high': '181.4100',
#    '3. low': '174.6900',
#    '4. close': '176.3700',
#    '5. adjusted close': '166.6666',
#    '6. volume': '32424274',
#    '7. dividend amount': '0.0000'},
#   '2022-04-29': {'1. open': '182.3400',
#    '2. high': '186.6900',
#    '3. low': '180.2000',
#    '4. close': '180.4600',
#    '5. adjusted close': '170.5316',
#    '6. volume': '50202639',
#    '7. dividend amount': '0.0000'},
#   '2022-04-22': {'1. open': '179.7300',
#    '2. high': '185.9400',
#    '3. low': '176.7400',
#    '4. close': '181.5400',
#    '5. adjusted close': '171.5522',
#    '6. volume': '43630658',
#    '7. dividend amount': '0.0000'},
#   '2022-04-14': {'1. open': '183.0000',
#    '2. high': '184.2000',
#    '3. low': '178.2000',
#    '4. close': '179.9000',
#    '5. adjusted close': '170.0024',
#    '6. volume': '23720887',
#    '7. dividend amount': '0.0000'},
#   '2022-04-08': {'1. open': '178.1900',
#    '2. high': '183.1870',
#    '3. low': '175.5200',
#    '4. close': '182.1200',
#    '5. adjusted close': '172.1003',
#    '6. volume': '39005548',
#    '7. dividend amount': '0.0000'},
#   '2022-04-01': {'1. open': '176.6500',
#    '2. high': '180.2100',
#    '3. low': '175.6000',
#    '4. close': '178.1900',
#    '5. adjusted close': '168.3865',
#    '6. volume': '35831200',
#    '7. dividend amount': '0.0000'},
#   '2022-03-25': {'1. open': '174.6600',
#    '2. high': '177.7000',
#    '3. low': '173.9100',
#    '4. close': '176.9200',
#    '5. adjusted close': '167.1864',
#    '6. volume': '30299125',
#    '7. dividend amount': '0.0000'},
#   '2022-03-18': {'1. open': '170.6800',
#    '2. high': '177.0000',
#    '3. low': '170.3500',
#    '4. close': '174.8400',
#    '5. adjusted close': '165.2208',
#    '6. volume': '48684269',
#    '7. dividend amount': '0.0000'},
#   '2022-03-11': {'1. open': '168.3000',
#    '2. high': '173.1200',
#    '3. low': '167.3600',
#    '4. close': '169.3500',
#    '5. adjusted close': '160.0329',
#    '6. volume': '41371756',
#    '7. dividend amount': '0.0000'},
#   '2022-03-04': {'1. open': '162.8700',
#    '2. high': '169.8600',
#    '3. low': '162.3802',
#    '4. close': '169.4800',
#    '5. adjusted close': '160.1557',
#    '6. volume': '38541142',
#    '7. dividend amount': '0.0000'},
#   '2022-02-25': {'1. open': '163.5750',
#    '2. high': '166.9850',
#    '3. low': '155.7200',
#    '4. close': '166.0000',
#    '5. adjusted close': '156.8672',
#    '6. volume': '39013772',
#    '7. dividend amount': '0.0000'},
#   '2022-02-18': {'1. open': '167.7100',
#    '2. high': '168.1000',
#    '3. low': '162.9400',
#    '4. close': '163.3600',
#    '5. adjusted close': '154.3724',
#    '6. volume': '36733813',
#    '7. dividend amount': '1.0600'},
#   '2022-02-11': {'1. open': '171.4100',
#    '2. high': '172.2400',
#    '3. low': '167.5400',
#    '4. close': '167.7100',
#    '5. adjusted close': '157.4614',
#    '6. volume': '41230187',
#    '7. dividend amount': '0.0000'},
#   '2022-02-04': {'1. open': '171.5000',
#    '2. high': '173.6200',
#    '3. low': '169.4300',
#    '4. close': '171.6300',
#    '5. adjusted close': '161.1418',
#    '6. volume': '36225205',
#    '7. dividend amount': '0.0000'},
#   '2022-01-28': {'1. open': '164.0000',
#    '2. high': '171.9100',
#    '3. low': '158.2600',
#    '4. close': '171.7900',
#    '5. adjusted close': '161.2920',
#    '6. volume': '56984033',
#    '7. dividend amount': '0.0000'},
#   '2022-01-21': {'1. open': '167.1000',
#    '2. high': '168.7200',
#    '3. low': '164.4700',
#    '4. close': '164.8700',
#    '5. adjusted close': '154.7949',
#    '6. volume': '29812465',
#    '7. dividend amount': '0.0000'},
#   '2022-01-14': {'1. open': '173.6900',
#    '2. high': '173.6900',
#    '3. low': '167.1500',
#    '4. close': '167.8400',
#    '5. adjusted close': '157.5834',
#    '6. volume': '35948336',
#    '7. dividend amount': '0.0000'},
#   '2022-01-07': {'1. open': '170.2100',
#    '2. high': '174.3000',
#    '3. low': '169.1000',
#    '4. close': '173.9500',
#    '5. adjusted close': '163.3200',
#    '6. volume': '34064878',
#    '7. dividend amount': '0.0000'},
#   '2021-12-31': {'1. open': '169.1400',
#    '2. high': '172.8750',
#    '3. low': '168.7000',
#    '4. close': '171.0700',
#    '5. adjusted close': '160.6160',
#    '6. volume': '19183429',
#    '7. dividend amount': '0.0000'},
#   '2021-12-23': {'1. open': '167.8100',
#    '2. high': '168.9500',
#    '3. low': '165.9800',
#    '4. close': '168.2500',
#    '5. adjusted close': '157.9684',
#    '6. volume': '23588592',
#    '7. dividend amount': '0.0000'},
#   '2021-12-17': {'1. open': '164.7500',
#    '2. high': '173.5100',
#    '3. low': '163.8000',
#    '4. close': '168.2300',
#    '5. adjusted close': '157.9496',
#    '6. volume': '55907556',
#    '7. dividend amount': '0.0000'},
#   '2021-12-10': {'1. open': '160.1900',
#    '2. high': '166.6900',
#    '3. low': '159.8300',
#    '4. close': '165.4900',
#    '5. adjusted close': '155.3770',
#    '6. volume': '39366110',
#    '7. dividend amount': '0.0000'},
#   '2021-12-03': {'1. open': '159.5000',
#    '2. high': '160.4200',
#    '3. low': '155.8500',
#    '4. close': '159.3800',
#    '5. adjusted close': '149.6404',
#    '6. volume': '54091870',
#    '7. dividend amount': '0.0000'},
#   '2021-11-26': {'1. open': '161.0300',
#    '2. high': '162.6400',
#    '3. low': '158.6600',
#    '4. close': '159.2000',
#    '5. adjusted close': '149.4714',
#    '6. volume': '29132051',
#    '7. dividend amount': '1.0600'},
#   '2021-11-19': {'1. open': '165.0000',
#    '2. high': '165.4600',
#    '3. low': '161.7800',
#    '4. close': '162.8900',
#    '5. adjusted close': '151.9275',
#    '6. volume': '34493988',
#    '7. dividend amount': '0.0000'},
#   '2021-11-12': {'1. open': '163.6800',
#    '2. high': '167.6200',
#    '3. low': '162.0100',
#    '4. close': '165.0100',
#    '5. adjusted close': '153.9048',
#    '6. volume': '39166933',
#    '7. dividend amount': '0.0000'},
#   '2021-11-05': {'1. open': '163.1600',
#    '2. high': '166.9818',
#    '3. low': '159.4000',
#    '4. close': '163.4300',
#    '5. adjusted close': '152.4312',
#    '6. volume': '35079024',
#    '7. dividend amount': '0.0000'},
#   '2021-10-29': {'1. open': '163.7200',
#    '2. high': '166.0300',
#    '3. low': '160.6100',
#    '4. close': '162.8800',
#    '5. adjusted close': '151.9182',
#    '6. volume': '35478893',
#    '7. dividend amount': '0.0000'},
#   '2021-10-22': {'1. open': '160.2500',
#    '2. high': '165.1500',
#    '3. low': '159.2000',
#    '4. close': '163.7200',
#    '5. adjusted close': '152.7016',
#    '6. volume': '32378526',
#    '7. dividend amount': '0.0000'},
#   '2021-10-15': {'1. open': '160.8600',
#    '2. high': '161.8550',
#    '3. low': '157.3400',
#    '4. close': '161.3000',
#    '5. adjusted close': '150.4445',
#    '6. volume': '29188979',
#    '7. dividend amount': '0.0000'},
#   '2021-10-08': {'1. open': '159.9900',
#    '2. high': '162.6100',
#    '3. low': '157.6737',
#    '4. close': '160.9300',
#    '5. adjusted close': '150.0994',
#    '6. volume': '30715318',
#    '7. dividend amount': '0.0000'},
#   '2021-10-01': {'1. open': '164.0000',
#    '2. high': '165.4000',
#    '3. low': '158.6200',
#    '4. close': '160.4700',
#    '5. adjusted close': '149.6704',
#    '6. volume': '34052794',
#    '7. dividend amount': '0.0000'},
#   '2021-09-24': {'1. open': '163.4800',
#    '2. high': '165.9800',
#    '3. low': '162.1650',
#    '4. close': '164.3600',
#    '5. adjusted close': '153.2986',
#    '6. volume': '28689262',
#    '7. dividend amount': '0.0000'},
#   '2021-09-17': {'1. open': '167.9200',
#    '2. high': '168.1200',
#    '3. low': '163.5550',
#    '4. close': '164.7500',
#    '5. adjusted close': '153.6623',
#    '6. volume': '38555987',
#    '7. dividend amount': '0.0000'},
#   '2021-09-10': {'1. open': '174.3500',
#    '2. high': '175.0300',
#    '3. low': '166.8700',
#    '4. close': '166.9700',
#    '5. adjusted close': '155.7329',
#    '6. volume': '25335496',
#    '7. dividend amount': '0.0000'},
#   '2021-09-03': {'1. open': '172.7900',
#    '2. high': '175.2200',
#    '3. low': '172.0600',
#    '4. close': '175.0400',
#    '5. adjusted close': '163.2598',
#    '6. volume': '24330108',
#    '7. dividend amount': '0.0000'},
#   '2021-08-27': {'1. open': '178.3900',
#    '2. high': '178.9300',
#    '3. low': '172.7500',
#    '4. close': '172.9300',
#    '5. adjusted close': '161.2918',
#    '6. volume': '29974507',
#    '7. dividend amount': '1.0600'},
#   '2021-08-20': {'1. open': '176.5500',
#    '2. high': '179.9200',
#    '3. low': '175.9500',
#    '4. close': '179.4400',
#    '5. adjusted close': '166.3708',
#    '6. volume': '29002934',
#    '7. dividend amount': '0.0000'},
#   '2021-08-13': {'1. open': '173.7200',
#    '2. high': '176.2900',
#    '3. low': '172.7800',
#    '4. close': '176.2500',
#    '5. adjusted close': '163.4131',
#    '6. volume': '22031769',
#    '7. dividend amount': '0.0000'},
#   '2021-08-06': {'1. open': '172.4700',
#    '2. high': '174.5900',
#    '3. low': '171.3000',
#    '4. close': '173.1100',
#    '5. adjusted close': '160.5018',
#    '6. volume': '23419985',
#    '7. dividend amount': '0.0000'},
#   '2021-07-30': {'1. open': '171.8200',
#    '2. high': '173.3801',
#    '3. low': '170.6700',
#    '4. close': '172.2000',
#    '5. adjusted close': '159.6581',
#    '6. volume': '26878261',
#    '7. dividend amount': '0.0000'},
#   '2021-07-23': {'1. open': '166.4800',
#    '2. high': '172.1751',
#    '3. low': '165.3200',
#    '4. close': '171.7900',
#    '5. adjusted close': '159.2779',
#    '6. volume': '36005428',
#    '7. dividend amount': '0.0000'},
#   '2021-07-16': {'1. open': '169.7300',
#    '2. high': '171.1800',
#    '3. low': '167.7200',
#    '4. close': '168.1000',
#    '5. adjusted close': '155.8567',
#    '6. volume': '31186751',
#    '7. dividend amount': '0.0000'},
#   '2021-07-09': {'1. open': '167.9100',
#    '2. high': '170.3700',
#    '3. low': '166.9900',
#    '4. close': '169.7500',
#    '5. adjusted close': '157.3865',
#    '6. volume': '24268711',
#    '7. dividend amount': '0.0000'},
#   '2021-07-02': {'1. open': '164.4400',
#    '2. high': '169.3000',
#    '3. low': '163.4100',
#    '4. close': '168.9800',
#    '5. adjusted close': '156.6726',
#    '6. volume': '30885941',
#    '7. dividend amount': '0.0000'},
#   '2021-06-25': {'1. open': '162.7700',
#    '2. high': '164.7800',
#    '3. low': '162.2500',
#    '4. close': '164.2100',
#    '5. adjusted close': '152.2500',
#    '6. volume': '32226586',
#    '7. dividend amount': '0.0000'},
#   '2021-06-18': {'1. open': '164.5000',
#    '2. high': '165.8600',
#    '3. low': '161.7900',
#    '4. close': '161.9800',
#    '5. adjusted close': '150.1824',
#    '6. volume': '35842243',
#    '7. dividend amount': '0.0000'},
#   '2021-06-11': {'1. open': '166.0000',
#    '2. high': '167.5750',
#    '3. low': '162.0700',
#    '4. close': '164.9600',
#    '5. adjusted close': '152.9454',
#    '6. volume': '32515430',
#    '7. dividend amount': '0.0000'},
#   '2021-06-04': {'1. open': '170.1500',
#    '2. high': '170.2000',
#    '3. low': '165.1100',
#    '4. close': '165.9700',
#    '5. adjusted close': '153.8818',
#    '6. volume': '29574004',
#    '7. dividend amount': '0.0000'},
#   '2021-05-28': {'1. open': '170.9000',
#    '2. high': '171.3500',
#    '3. low': '168.2800',
#    '4. close': '169.2500',
#    '5. adjusted close': '156.9229',
#    '6. volume': '32882643',
#    '7. dividend amount': '1.0600'},
#   '2021-05-21': {'1. open': '170.4000',
#    '2. high': '172.7400',
#    '3. low': '168.0354',
#    '4. close': '170.9600',
#    '5. adjusted close': '157.5293',
#    '6. volume': '28457354',
#    '7. dividend amount': '0.0000'},
#   '2021-05-14': {'1. open': '169.9000',
#    '2. high': '171.6100',
#    '3. low': '166.9700',
#    '4. close': '170.2200',
#    '5. adjusted close': '156.8475',
#    '6. volume': '37150369',
#    '7. dividend amount': '0.0000'},
#   '2021-05-07': {'1. open': '163.6000',
#    '2. high': '169.1800',
#    '3. low': '163.1200',
#    '4. close': '168.5000',
#    '5. adjusted close': '155.2626',
#    '6. volume': '32754511',
#    '7. dividend amount': '0.0000'},
#   '2021-04-30': {'1. open': '165.2100',
#    '2. high': '165.4100',
#    '3. low': '161.6500',
#    '4. close': '162.7300',
#    '5. adjusted close': '149.9459',
#    '6. volume': '35166823',
#    '7. dividend amount': '0.0000'},
#   '2021-04-23': {'1. open': '162.5000',
#    '2. high': '167.7899',
#    '3. low': '160.8400',
#    '4. close': '165.5200',
#    '5. adjusted close': '152.5167',
#    '6. volume': '42003627',
#    '7. dividend amount': '0.0000'},
#   '2021-04-16': {'1. open': '161.0900',
#    '2. high': '162.5100',
#    '3. low': '156.5300',
#    '4. close': '162.2400',
#    '5. adjusted close': '149.4944',
#    '6. volume': '47739433',
#    '7. dividend amount': '0.0000'},
#   '2021-04-09': {'1. open': '163.6400',
#    '2. high': '164.7500',
#    '3. low': '159.7800',
#    '4. close': '161.2500',
#    '5. adjusted close': '148.5821',
#    '6. volume': '30527101',
#    '7. dividend amount': '0.0000'},
#   '2021-04-01': {'1. open': '163.8300',
#    '2. high': '167.0300',
#    '3. low': '162.2600',
#    '4. close': '162.8300',
#    '5. adjusted close': '150.0380',
#    '6. volume': '31282669',
#    '7. dividend amount': '0.0000'},
#   '2021-03-26': {'1. open': '158.3100',
#    '2. high': '165.1000',
#    '3. low': '158.0000',
#    '4. close': '164.9300',
#    '5. adjusted close': '151.9730',
#    '6. volume': '34981539',
#    '7. dividend amount': '0.0000'},
#   '2021-03-19': {'1. open': '159.7500',
#    '2. high': '161.7300',
#    '3. low': '158.5000',
#    '4. close': '160.0400',
#    '5. adjusted close': '147.4672',
#    '6. volume': '37589890',
#    '7. dividend amount': '0.0000'},
#   '2021-03-12': {'1. open': '157.0000',
#    '2. high': '160.7500',
#    '3. low': '155.9800',
#    '4. close': '159.6000',
#    '5. adjusted close': '147.0618',
#    '6. volume': '32423965',
#    '7. dividend amount': '0.0000'},
#   '2021-03-05': {'1. open': '161.4500',
#    '2. high': '161.5300',
#    '3. low': '151.4700',
#    '4. close': '156.1000',
#    '5. adjusted close': '143.8367',
#    '6. volume': '46026700',
#    '7. dividend amount': '0.0000'},
#   '2021-02-26': {'1. open': '161.8700',
#    '2. high': '164.3900',
#    '3. low': '157.9700',
#    '4. close': '158.4600',
#    '5. adjusted close': '146.0113',
#    '6. volume': '47436388',
#    '7. dividend amount': '1.0100'},
#   '2021-02-19': {'1. open': '166.5800',
#    '2. high': '167.0500',
#    '3. low': '162.9100',
#    '4. close': '162.9800',
#    '5. adjusted close': '149.2450',
#    '6. volume': '25582688',
#    '7. dividend amount': '0.0000'},
#   '2021-02-12': {'1. open': '165.0300',
#    '2. high': '167.9400',
#    '3. low': '163.8800',
#    '4. close': '166.5800',
#    '5. adjusted close': '152.5416',
#    '6. volume': '26753563',
#    '7. dividend amount': '0.0000'},
#   '2021-02-05': {'1. open': '165.3100',
#    '2. high': '165.4400',
#    '3. low': '159.5700',
#    '4. close': '164.4500',
#    '5. adjusted close': '150.5911',
#    '6. volume': '45930529',
#    '7. dividend amount': '0.0000'},
#   '2021-01-29': {'1. open': '165.0100',
#    '2. high': '173.6500',
#    '3. low': '160.5527',
#    '4. close': '163.1300',
#    '5. adjusted close': '149.3824',
#    '6. volume': '69787677',
#    '7. dividend amount': '0.0000'},
#   '2021-01-22': {'1. open': '162.0000',
#    '2. high': '165.1550',
#    '3. low': '160.0600',
#    '4. close': '163.5500',
#    '5. adjusted close': '149.7670',
#    '6. volume': '30857193',
#    '7. dividend amount': '0.0000'},
#   '2021-01-15': {'1. open': '160.5600',
#    '2. high': '161.9500',
#    '3. low': '156.7500',
#    '4. close': '160.3000',
#    '5. adjusted close': '146.7909',
#    '6. volume': '38249057',
#    '7. dividend amount': '0.0000'},
#   '2021-01-08': {'1. open': '157.2400',
#    '2. high': '161.1000',
#    '3. low': '154.1300',
#    '4. close': '160.0400',
#    '5. adjusted close': '146.5528',
#    '6. volume': '45574340',
#    '7. dividend amount': '0.0000'},
#   '2020-12-31': {'1. open': '153.3200',
#    '2. high': '157.6600',
#    '3. low': '152.3000',
#    '4. close': '157.3800',
#    '5. adjusted close': '144.1169',
#    '6. volume': '19544047',
#    '7. dividend amount': '0.0000'},
#   '2020-12-24': {'1. open': '152.0100',
#    '2. high': '153.9000',
#    '3. low': '150.0500',
#    '4. close': '152.4700',
#    '5. adjusted close': '139.6207',
#    '6. volume': '19318720',
#    '7. dividend amount': '0.0000'},
#   '2020-12-18': {'1. open': '153.2500',
#    '2. high': '155.1000',
#    '3. low': '148.9900',
#    '4. close': '154.5100',
#    '5. adjusted close': '141.4888',
#    '6. volume': '51705652',
#    '7. dividend amount': '0.0000'},
#   '2020-12-11': {'1. open': '149.3500',
#    '2. high': '153.5000',
#    '3. low': '148.5100',
#    '4. close': '152.9500',
#    '5. adjusted close': '140.0603',
#    '6. volume': '36780842',
#    '7. dividend amount': '0.0000'},
#   '2020-12-04': {'1. open': '144.2300',
#    '2. high': '150.3100',
#    '3. low': '143.0600',
#    '4. close': '150.2700',
#    '5. adjusted close': '137.6061',
#    '6. volume': '47162070',
#    '7. dividend amount': '0.0000'},
#   '2020-11-27': {'1. open': '146.0100',
#    '2. high': '146.0100',
#    '3. low': '142.8600',
#    '4. close': '144.0000',
#    '5. adjusted close': '131.8645',
#    '6. volume': '28997639',
#    '7. dividend amount': '1.0100'},
#   '2020-11-20': {'1. open': '150.9200',
#    '2. high': '151.3000',
#    '3. low': '145.5869',
#    '4. close': '146.3600',
#    '5. adjusted close': '133.0913',
#    '6. volume': '34568986',
#    '7. dividend amount': '0.0000'},
#   '2020-11-13': {'1. open': '148.4250',
#    '2. high': '150.4100',
#    '3. low': '144.9200',
#    '4. close': '149.9000',
#    '5. adjusted close': '136.3104',
#    '6. volume': '36729227',
#    '7. dividend amount': '0.0000'},
#   '2020-11-06': {'1. open': '138.9800',
#    '2. high': '143.1900',
#    '3. low': '137.4900',
#    '4. close': '142.2500',
#    '5. adjusted close': '129.3539',
#    '6. volume': '37673220',
#    '7. dividend amount': '0.0000'},
#   '2020-10-30': {'1. open': '144.4300',
#    '2. high': '144.7700',
#    '3. low': '133.6500',
#    '4. close': '137.1100',
#    '5. adjusted close': '124.6799',
#    '6. volume': '34815762',
#    '7. dividend amount': '0.0000'},
#   '2020-10-23': {'1. open': '148.5300',
#    '2. high': '148.9000',
#    '3. low': '143.8400',
#    '4. close': '145.2400',
#    '5. adjusted close': '132.0728',
#    '6. volume': '27233268',
#    '7. dividend amount': '0.0000'},
#   '2020-10-16': {'1. open': '151.6000',
#    '2. high': '153.1420',
#    '3. low': '146.3300',
#    '4. close': '148.1000',
#    '5. adjusted close': '134.6736',
#    '6. volume': '38115206',
#    '7. dividend amount': '0.0000'},
#   '2020-10-09': {'1. open': '147.0000',
#    '2. high': '151.4800',
#    '3. low': '145.8100',
#    '4. close': '150.9700',
#    '5. adjusted close': '137.2834',
#    '6. volume': '25181740',
#    '7. dividend amount': '0.0000'},
#   '2020-10-02': {'1. open': '146.7300',
#    '2. high': '149.7300',
#    '3. low': '145.8300',
#    '4. close': '146.2400',
#    '5. adjusted close': '132.9822',
#    '6. volume': '33045306',
#    '7. dividend amount': '0.0000'},
#   '2020-09-25': {'1. open': '147.5800',
#    '2. high': '147.9300',
#    '3. low': '142.9600',
#    '4. close': '145.6600',
#    '5. adjusted close': '132.4548',
#    '6. volume': '32800907',
#    '7. dividend amount': '0.0000'},
#   '2020-09-18': {'1. open': '148.1200',
#    '2. high': '150.5900',
#    '3. low': '146.0500',
#    '4. close': '149.1800',
#    '5. adjusted close': '135.6557',
#    '6. volume': '29993979',
#    '7. dividend amount': '0.0000'},
#   '2020-09-11': {'1. open': '150.2500',
#    '2. high': '151.1000',
#    '3. low': '146.5200',
#    '4. close': '147.7800',
#    '5. adjusted close': '134.3826',
#    '6. volume': '25844001',
#    '7. dividend amount': '0.0000'},
#   '2020-09-04': {'1. open': '153.0000',
#    '2. high': '155.4700',
#    '3. low': '147.1300',
#    '4. close': '148.5900',
#    '5. adjusted close': '135.1191',
#    '6. volume': '35426649',
#    '7. dividend amount': '0.0000'},
#   '2020-08-28': {'1. open': '152.7400',
#    '2. high': '153.7000',
#    '3. low': '150.3500',
#    '4. close': '153.6400',
#    '5. adjusted close': '139.7113',
#    '6. volume': '28230822',
#    '7. dividend amount': '1.0100'},
#   '2020-08-21': {'1. open': '148.3200',
#    '2. high': '153.6500',
#    '3. low': '148.2300',
#    '4. close': '152.7600',
#    '5. adjusted close': '137.9951',
#    '6. volume': '27898287',
#    '7. dividend amount': '0.0000'},
#   '2020-08-14': {'1. open': '148.8600',
#    '2. high': '150.2400',
#    '3. low': '146.3700',
#    '4. close': '148.2400',
#    '5. adjusted close': '133.9119',
#    '6. volume': '25138782',
#    '7. dividend amount': '0.0000'},
#   '2020-08-07': {'1. open': '146.3900',
#    '2. high': '149.3100',
#    '3. low': '145.8247',
#    '4. close': '148.6000',
#    '5. adjusted close': '134.2371',
#    '6. volume': '22208041',
#    '7. dividend amount': '0.0000'},
#   '2020-07-31': {'1. open': '147.3700',
#    '2. high': '148.9200',
#    '3. low': '143.9600',
#    '4. close': '145.7600',
#    '5. adjusted close': '131.6716',
#    '6. volume': '29186964',
#    '7. dividend amount': '0.0000'},
#   '2020-07-24': {'1. open': '150.2300',
#    '2. high': '151.6700',
#    '3. low': '147.0300',
#    '4. close': '148.1200',
#    '5. adjusted close': '133.8035',
#    '6. volume': '29647444',
#    '7. dividend amount': '0.0000'},
#   '2020-07-17': {'1. open': '143.6100',
#    '2. high': '150.5800',
#    '3. low': '143.2800',
#    '4. close': '149.3500',
#    '5. adjusted close': '134.9147',
#    '6. volume': '39584655',
#    '7. dividend amount': '0.0000'},
#   '2020-07-10': {'1. open': '142.1700',
#    '2. high': '144.4300',
#    '3. low': '140.5800',
#    '4. close': '142.3700',
#    '5. adjusted close': '128.6093',
#    '6. volume': '28047041',
#    '7. dividend amount': '0.0000'},
#   '2020-07-02': {'1. open': '138.7400',
#    '2. high': '141.8400',
#    '3. low': '137.8400',
#    '4. close': '140.9700',
#    '5. adjusted close': '127.3446',
#    '6. volume': '24390175',
#    '7. dividend amount': '0.0000'},
#   '2020-06-26': {'1. open': '143.4700',
#    '2. high': '144.0800',
#    '3. low': '137.0200',
#    '4. close': '137.8100',
#    '5. adjusted close': '124.4900',
#    '6. volume': '39678683',
#    '7. dividend amount': '0.0000'},
#   '2020-06-19': {'1. open': '141.0000',
#    '2. high': '145.8800',
#    '3. low': '139.3900',
#    '4. close': '143.8300',
#    '5. adjusted close': '129.9282',
#    '6. volume': '38194672',
#    '7. dividend amount': '0.0000'},
#   '2020-06-12': {'1. open': '145.8800',
#    '2. high': '150.0300',
#    '3. low': '140.2800',
#    '4. close': '142.1500',
#    '5. adjusted close': '128.4106',
#    '6. volume': '46488627',
#    '7. dividend amount': '0.0000'},
#   '2020-06-05': {'1. open': '147.2900',
#    '2. high': '149.6400',
#    '3. low': '145.5800',
#    '4. close': '147.3000',
#    '5. adjusted close': '133.0628',
#    '6. volume': '36446924',
#    '7. dividend amount': '0.0000'},
#   '2020-05-29': {'1. open': '146.1900',
#    '2. high': '149.3500',
#    '3. low': '143.0100',
#    '4. close': '148.7500',
#    '5. adjusted close': '134.3726',
#    '6. volume': '29712669',
#    '7. dividend amount': '0.0000'},
#   '2020-05-22': {'1. open': '152.4900',
#    '2. high': '153.6200',
#    '3. low': '144.0600',
#    '4. close': '144.3700',
#    '5. adjusted close': '130.4160',
#    '6. volume': '31878835',
#    '7. dividend amount': '1.0100'},
#   '2020-05-15': {'1. open': '148.4500',
#    '2. high': '150.4800',
#    '3. low': '144.2600',
#    '4. close': '150.4400',
#    '5. adjusted close': '134.9552',
#    '6. volume': '37092948',
#    '7. dividend amount': '0.0000'},
#   '2020-05-08': {'1. open': '148.7700',
#    '2. high': '150.7800',
#    '3. low': '147.0900',
#    '4. close': '148.7000',
#    '5. adjusted close': '133.3943',
#    '6. volume': '30229206',
#    '7. dividend amount': '0.0000'},
#   '2020-05-01': {'1. open': '154.8100',
#    '2. high': '156.0500',
#    '3. low': '146.7900',
#    '4. close': '148.2900',
#    '5. adjusted close': '133.0265',
#    '6. volume': '48888300',
#    '7. dividend amount': '0.0000'},
#   '2020-04-24': {'1. open': '150.9300',
#    '2. high': '157.0000',
#    '3. low': '148.5700',
#    '4. close': '154.8600',
#    '5. adjusted close': '138.9202',
#    '6. volume': '53013551',
#    '7. dividend amount': '0.0000'},
#   '2020-04-17': {'1. open': '140.0000',
#    '2. high': '152.3000',
#    '3. low': '137.8400',
#    '4. close': '152.0200',
#    '5. adjusted close': '136.3725',
#    '6. volume': '56977544',
#    '7. dividend amount': '0.0000'},
#   '2020-04-09': {'1. open': '137.0100',
#    '2. high': '145.4200',
#    '3. low': '135.5400',
#    '4. close': '141.2300',
#    '5. adjusted close': '126.6932',
#    '6. volume': '48425413',
#    '7. dividend amount': '0.0000'},
#   '2020-04-03': {'1. open': '128.4600',
#    '2. high': '135.7100',
#    '3. low': '125.5000',
#    '4. close': '134.1700',
#    '5. adjusted close': '120.3598',
#    '6. volume': '71633233',
#    '7. dividend amount': '0.0000'},
#   '2020-03-27': {'1. open': '117.0000',
#    '2. high': '127.6200',
#    '3. low': '109.1600',
#    '4. close': '123.1600',
#    '5. adjusted close': '110.4831',
#    '6. volume': '79575060',
#    '7. dividend amount': '0.0000'},
#   '2020-03-20': {'1. open': '123.5700',
#    '2. high': '136.7700',
#    '3. low': '118.1300',
#    '4. close': '119.8900',
#    '5. adjusted close': '107.5497',
#    '6. volume': '93511731',
#    '7. dividend amount': '0.0000'},
#   '2020-03-13': {'1. open': '136.3300',
#    '2. high': '141.9500',
#    '3. low': '124.5000',
#    '4. close': '134.2900',
#    '5. adjusted close': '120.4675',
#    '6. volume': '85369777',
#    '7. dividend amount': '0.0000'},
#   '2020-03-06': {'1. open': '134.7800',
#    '2. high': '143.6400',
#    '3. low': '133.1000',
#    '4. close': '142.0300',
#    '5. adjusted close': '127.4108',
#    '6. volume': '59302386',
#    '7. dividend amount': '0.0000'},
#   '2020-02-28': {'1. open': '146.5000',
#    '2. high': '149.0000',
#    '3. low': '130.8200',
#    '4. close': '134.4800',
#    '5. adjusted close': '120.6379',
#    '6. volume': '63595944',
#    '7. dividend amount': '0.9500'},
#   '2020-02-21': {'1. open': '150.4700',
#    '2. high': '150.7400',
#    '3. low': '147.4000',
#    '4. close': '149.9300',
#    '5. adjusted close': '133.6276',
#    '6. volume': '28585424',
#    '7. dividend amount': '0.0000'},
#   '2020-02-14': {'1. open': '151.6800',
# ...
#   '2006-08-04': {'1. open': '62.6700',
#    '2. high': '63.7000',
#    '3. low': '62.2900',
#    '4. close': '63.5300',
#    '5. adjusted close': '38.0128',
#    '6. volume': '32236600',
#    '7. dividend amount': '0.0000'},
#   '2006-07-28': {'1. open': '61.6700',
#    '2. high': '63.0000',
#    '3. low': '61.4900',
#    '4. close': '62.9200',
#    '5. adjusted close': '37.6478',
#    '6. volume': '35237000',
#    '7. dividend amount': '0.0000'},
#   '2006-07-21': {'1. open': '60.5500',
#    '2. high': '61.9900',
#    '3. low': '59.6842',
#    '4. close': '61.7300',
#    '5. adjusted close': '36.9358',
#    '6. volume': '38269700',
#    '7. dividend amount': '0.0000'},
#   '2006-07-14': {'1. open': '60.8500',
#    '2. high': '61.0600',
#    '3. low': '60.1500',
#    '4. close': '60.4600',
#    '5. adjusted close': '36.1759',
#    '6. volume': '33559000',
#    '7. dividend amount': '0.0000'},
#   '2006-07-07': {'1. open': '60.1300',
#    '2. high': '60.8700',
#    '3. low': '59.8000',
#    '4. close': '60.6200',
#    '5. adjusted close': '36.2716',
#    '6. volume': '20843700',
#    '7. dividend amount': '0.0000'},
#   '2006-06-30': {'1. open': '59.5100',
#    '2. high': '60.3500',
#    '3. low': '58.9700',
#    '4. close': '59.9200',
#    '5. adjusted close': '35.8528',
#    '6. volume': '54105100',
#    '7. dividend amount': '0.0000'},
#   '2006-06-23': {'1. open': '61.6000',
#    '2. high': '62.0000',
#    '3. low': '59.7500',
#    '4. close': '61.3200',
#    '5. adjusted close': '36.6904',
#    '6. volume': '36733700',
#    '7. dividend amount': '0.0000'},
#   '2006-06-16': {'1. open': '61.4500',
#    '2. high': '61.7500',
#    '3. low': '60.9200',
#    '4. close': '61.6800',
#    '5. adjusted close': '36.9058',
#    '6. volume': '48080600',
#    '7. dividend amount': '0.0000'},
#   '2006-06-09': {'1. open': '60.3500',
#    '2. high': '61.7500',
#    '3. low': '60.0900',
#    '4. close': '61.5100',
#    '5. adjusted close': '36.8041',
#    '6. volume': '48148500',
#    '7. dividend amount': '0.0000'},
#   '2006-06-02': {'1. open': '60.4800',
#    '2. high': '61.0100',
#    '3. low': '59.8200',
#    '4. close': '60.7400',
#    '5. adjusted close': '36.3434',
#    '6. volume': '28429600',
#    '7. dividend amount': '0.0000'},
#   '2006-05-26': {'1. open': '59.9000',
#    '2. high': '60.9300',
#    '3. low': '59.6500',
#    '4. close': '60.6900',
#    '5. adjusted close': '36.3135',
#    '6. volume': '47735800',
#    '7. dividend amount': '0.3750'},
#   '2006-05-19': {'1. open': '58.9700',
#    '2. high': '60.7900',
#    '3. low': '58.8400',
#    '4. close': '59.9000',
#    '5. adjusted close': '35.6198',
#    '6. volume': '54427200',
#    '7. dividend amount': '0.0000'},
#   '2006-05-12': {'1. open': '58.7000',
#    '2. high': '59.2500',
#    '3. low': '58.2500',
#    '4. close': '58.8300',
#    '5. adjusted close': '34.9835',
#    '6. volume': '40979800',
#    '7. dividend amount': '0.0000'},
#   '2006-05-05': {'1. open': '58.7100',
#    '2. high': '58.9600',
#    '3. low': '58.1900',
#    '4. close': '58.7000',
#    '5. adjusted close': '34.9062',
#    '6. volume': '37359700',
#    '7. dividend amount': '0.0000'},
#   '2006-04-28': {'1. open': '58.3400',
#    '2. high': '58.9200',
#    '3. low': '58.1200',
#    '4. close': '58.6100',
#    '5. adjusted close': '34.8527',
#    '6. volume': '47419200',
#    '7. dividend amount': '0.0000'},
#   '2006-04-21': {'1. open': '57.6800',
#    '2. high': '58.6000',
#    '3. low': '57.4600',
#    '4. close': '58.3700',
#    '5. adjusted close': '34.7100',
#    '6. volume': '48248500',
#    '7. dividend amount': '0.0000'},
#   '2006-04-13': {'1. open': '57.8500',
#    '2. high': '58.0200',
#    '3. low': '57.3200',
#    '4. close': '57.9100',
#    '5. adjusted close': '34.4365',
#    '6. volume': '32471700',
#    '7. dividend amount': '0.0000'},
#   '2006-04-07': {'1. open': '59.4900',
#    '2. high': '59.7600',
#    '3. low': '57.7000',
#    '4. close': '57.8300',
#    '5. adjusted close': '34.3889',
#    '6. volume': '42993900',
#    '7. dividend amount': '0.0000'},
#   '2006-03-31': {'1. open': '60.0700',
#    '2. high': '60.4000',
#    '3. low': '59.0600',
#    '4. close': '59.2200',
#    '5. adjusted close': '35.2155',
#    '6. volume': '39393700',
#    '7. dividend amount': '0.0000'},
#   '2006-03-24': {'1. open': '60.4000',
#    '2. high': '61.1000',
#    '3. low': '60.2900',
#    '4. close': '60.3900',
#    '5. adjusted close': '35.9112',
#    '6. volume': '32959500',
#    '7. dividend amount': '0.0000'},
#   '2006-03-17': {'1. open': '59.0700',
#    '2. high': '60.4000',
#    '3. low': '59.0000',
#    '4. close': '60.3400',
#    '5. adjusted close': '35.8815',
#    '6. volume': '45306300',
#    '7. dividend amount': '0.0000'},
#   '2006-03-10': {'1. open': '57.5700',
#    '2. high': '59.0400',
#    '3. low': '57.5100',
#    '4. close': '59.0400',
#    '5. adjusted close': '35.1084',
#    '6. volume': '42145000',
#    '7. dividend amount': '0.0000'},
#   '2006-03-03': {'1. open': '57.9600',
#    '2. high': '58.5500',
#    '3. low': '57.4200',
#    '4. close': '57.4700',
#    '5. adjusted close': '34.1748',
#    '6. volume': '37348100',
#    '7. dividend amount': '0.0000'},
#   '2006-02-24': {'1. open': '59.1300',
#    '2. high': '59.3200',
#    '3. low': '57.4200',
#    '4. close': '57.7600',
#    '5. adjusted close': '34.3473',
#    '6. volume': '35262800',
#    '7. dividend amount': '0.3300'},
#   '2006-02-17': {'1. open': '58.3800',
#    '2. high': '59.4500',
#    '3. low': '58.0400',
#    '4. close': '59.0700',
#    '5. adjusted close': '34.9267',
#    '6. volume': '41814200',
#    '7. dividend amount': '0.0000'},
#   '2006-02-10': {'1. open': '57.5000',
#    '2. high': '59.7100',
#    '3. low': '56.6500',
#    '4. close': '58.3900',
#    '5. adjusted close': '34.5246',
#    '6. volume': '55874400',
#    '7. dividend amount': '0.0000'},
#   '2006-02-03': {'1. open': '58.7100',
#    '2. high': '58.7500',
#    '3. low': '57.0200',
#    '4. close': '57.3800',
#    '5. adjusted close': '33.9275',
#    '6. volume': '66881300',
#    '7. dividend amount': '0.0000'},
#   '2006-01-27': {'1. open': '60.7500',
#    '2. high': '61.2400',
#    '3. low': '58.0400',
#    '4. close': '58.7100',
#    '5. adjusted close': '34.7139',
#    '6. volume': '80081100',
#    '7. dividend amount': '0.0000'},
#   '2006-01-20': {'1. open': '61.3100',
#    '2. high': '62.6200',
#    '3. low': '60.7300',
#    '4. close': '60.8000',
#    '5. adjusted close': '35.9496',
#    '6. volume': '35739600',
#    '7. dividend amount': '0.0000'},
#   '2006-01-13': {'1. open': '62.5200',
#    '2. high': '63.1000',
#    '3. low': '61.4200',
#    '4. close': '61.8200',
#    '5. adjusted close': '36.5527',
#    '6. volume': '36890500',
#    '7. dividend amount': '0.0000'},
#   '2006-01-06': {'1. open': '61.0700',
#    '2. high': '62.9500',
#    '3. low': '61.0500',
#    '4. close': '62.6000',
#    '5. adjusted close': '37.0139',
#    '6. volume': '35543000',
#    '7. dividend amount': '0.0000'},
#   '2005-12-30': {'1. open': '61.1200',
#    '2. high': '61.2000',
#    '3. low': '60.0300',
#    '4. close': '60.1000',
#    '5. adjusted close': '35.5357',
#    '6. volume': '22513900',
#    '7. dividend amount': '0.0000'},
#   '2005-12-23': {'1. open': '61.5500',
#    '2. high': '62.0000',
#    '3. low': '60.5600',
#    '4. close': '61.1100',
#    '5. adjusted close': '36.1329',
#    '6. volume': '32638100',
#    '7. dividend amount': '0.0000'},
#   '2005-12-16': {'1. open': '60.1500',
#    '2. high': '61.3500',
#    '3. low': '59.9900',
#    '4. close': '60.8600',
#    '5. adjusted close': '35.9851',
#    '6. volume': '51085100',
#    '7. dividend amount': '0.0000'},
#   '2005-12-09': {'1. open': '61.6000',
#    '2. high': '62.0000',
#    '3. low': '59.7600',
#    '4. close': '60.1000',
#    '5. adjusted close': '35.5357',
#    '6. volume': '69850900',
#    '7. dividend amount': '0.0000'},
#   '2005-12-02': {'1. open': '62.7500',
#    '2. high': '62.9500',
#    '3. low': '61.2000',
#    '4. close': '61.2100',
#    '5. adjusted close': '36.1920',
#    '6. volume': '42851800',
#    '7. dividend amount': '0.0000'},
#   '2005-11-25': {'1. open': '62.5500',
#    '2. high': '62.5500',
#    '3. low': '61.1500',
#    '4. close': '62.1500',
#    '5. adjusted close': '36.7478',
#    '6. volume': '34470800',
#    '7. dividend amount': '0.0000'},
#   '2005-11-18': {'1. open': '61.0700',
#    '2. high': '63.7800',
#    '3. low': '60.4300',
#    '4. close': '62.5500',
#    '5. adjusted close': '36.9844',
#    '6. volume': '83973900',
#    '7. dividend amount': '0.3300'},
#   '2005-11-11': {'1. open': '60.5000',
#    '2. high': '61.6000',
#    '3. low': '60.2000',
#    '4. close': '60.9200',
#    '5. adjusted close': '35.8315',
#    '6. volume': '36240500',
#    '7. dividend amount': '0.0000'},
#   '2005-11-04': {'1. open': '62.9100',
#    '2. high': '63.0000',
#    '3. low': '60.0000',
#    '4. close': '60.8800',
#    '5. adjusted close': '35.8080',
#    '6. volume': '67183400',
#    '7. dividend amount': '0.0000'},
#   '2005-10-28': {'1. open': '64.2000',
#    '2. high': '64.5000',
#    '3. low': '61.0500',
#    '4. close': '62.9500',
#    '5. adjusted close': '37.0255',
#    '6. volume': '47773300',
#    '7. dividend amount': '0.0000'},
#   '2005-10-21': {'1. open': '63.6500',
#    '2. high': '64.5900',
#    '3. low': '62.6600',
#    '4. close': '64.0700',
#    '5. adjusted close': '37.6843',
#    '6. volume': '65152600',
#    '7. dividend amount': '0.0000'},
#   '2005-10-14': {'1. open': '61.2800',
#    '2. high': '64.5999',
#    '3. low': '60.5300',
#    '4. close': '63.7000',
#    '5. adjusted close': '37.4667',
#    '6. volume': '56617000',
#    '7. dividend amount': '0.0000'},
#   '2005-10-07': {'1. open': '63.1800',
#    '2. high': '63.2800',
#    '3. low': '61.1200',
#    '4. close': '61.3400',
#    '5. adjusted close': '36.0786',
#    '6. volume': '44845800',
#    '7. dividend amount': '0.0000'},
#   '2005-09-30': {'1. open': '64.2300',
#    '2. high': '64.4500',
#    '3. low': '62.9000',
#    '4. close': '63.2800',
#    '5. adjusted close': '37.2196',
#    '6. volume': '29730900',
#    '7. dividend amount': '0.0000'},
#   '2005-09-23': {'1. open': '65.1900',
#    '2. high': '65.3300',
#    '3. low': '63.8900',
#    '4. close': '63.9900',
#    '5. adjusted close': '37.6372',
#    '6. volume': '34740500',
#    '7. dividend amount': '0.0000'},
#   '2005-09-16': {'1. open': '64.7300',
#    '2. high': '65.2200',
#    '3. low': '64.0000',
#    '4. close': '65.1800',
#    '5. adjusted close': '38.3372',
#    '6. volume': '37891300',
#    '7. dividend amount': '0.0000'},
#   '2005-09-09': {'1. open': '63.2500',
#    '2. high': '65.0000',
#    '3. low': '63.2100',
#    '4. close': '64.7300',
#    '5. adjusted close': '38.0725',
#    '6. volume': '26791300',
#    '7. dividend amount': '0.0000'},
#   '2005-09-02': {'1. open': '61.7800',
#    '2. high': '63.7300',
#    '3. low': '61.6500',
#    '4. close': '62.9000',
#    '5. adjusted close': '36.9961',
#    '6. volume': '32244900',
#    '7. dividend amount': '0.0000'},
#   '2005-08-26': {'1. open': '64.0000',
#    '2. high': '64.0600',
#    '3. low': '61.9400',
#    '4. close': '61.9400',
#    '5. adjusted close': '36.4315',
#    '6. volume': '33660400',
#    '7. dividend amount': '0.0000'},
#   '2005-08-19': {'1. open': '63.4200',
#    '2. high': '64.4400',
#    '3. low': '62.8400',
#    '4. close': '63.5700',
#    '5. adjusted close': '37.3902',
#    '6. volume': '31860900',
#    '7. dividend amount': '0.3300'},
#   '2005-08-12': {'1. open': '63.5400',
#    '2. high': '64.6600',
#    '3. low': '63.2300',
#    '4. close': '63.5600',
#    '5. adjusted close': '37.1912',
#    '6. volume': '23492900',
#    '7. dividend amount': '0.0000'},
#   '2005-08-05': {'1. open': '64.2500',
#    '2. high': '65.3500',
#    '3. low': '63.5400',
#    '4. close': '63.5400',
#    '5. adjusted close': '37.1795',
#    '6. volume': '27062000',
#    '7. dividend amount': '0.0000'},
#   '2005-07-29': {'1. open': '64.2500',
#    '2. high': '64.8400',
#    '3. low': '62.6700',
#    '4. close': '63.9600',
#    '5. adjusted close': '37.4253',
#    '6. volume': '42706600',
#    '7. dividend amount': '0.0000'},
#   '2005-07-22': {'1. open': '64.8500',
#    '2. high': '65.0700',
#    '3. low': '63.9800',
#    '4. close': '64.3200',
#    '5. adjusted close': '37.6360',
#    '6. volume': '39568500',
#    '7. dividend amount': '0.0000'},
#   '2005-07-15': {'1. open': '64.2800',
#    '2. high': '65.1500',
#    '3. low': '64.1100',
#    '4. close': '65.0300',
#    '5. adjusted close': '38.0514',
#    '6. volume': '31445800',
#    '7. dividend amount': '0.0000'},
#   '2005-07-08': {'1. open': '64.4000',
#    '2. high': '65.2500',
#    '3. low': '63.5200',
#    '4. close': '64.2800',
#    '5. adjusted close': '37.6125',
#    '6. volume': '29469300',
#    '7. dividend amount': '0.0000'},
#   '2005-07-01': {'1. open': '65.5200',
#    '2. high': '66.1000',
#    '3. low': '64.4300',
#    '4. close': '64.9500',
#    '5. adjusted close': '38.0046',
#    '6. volume': '36842700',
#    '7. dividend amount': '0.0000'},
#   '2005-06-24': {'1. open': '66.3520',
#    '2. high': '66.8000',
#    '3. low': '65.0000',
#    '4. close': '65.5800',
#    '5. adjusted close': '38.3732',
#    '6. volume': '52988900',
#    '7. dividend amount': '0.0000'},
#   '2005-06-17': {'1. open': '66.2500',
#    '2. high': '66.9500',
#    '3. low': '65.4100',
#    '4. close': '66.5600',
#    '5. adjusted close': '38.9467',
#    '6. volume': '32773200',
#    '7. dividend amount': '0.0000'},
#   '2005-06-10': {'1. open': '66.5900',
#    '2. high': '66.9400',
#    '3. low': '65.7300',
#    '4. close': '66.4800',
#    '5. adjusted close': '38.8998',
#    '6. volume': '28336000',
#    '7. dividend amount': '0.0000'},
#   '2005-06-03': {'1. open': '67.6800',
#    '2. high': '67.6900',
#    '3. low': '66.3600',
#    '4. close': '66.4400',
#    '5. adjusted close': '38.8764',
#    '6. volume': '24652100',
#    '7. dividend amount': '0.0000'},
#   '2005-05-27': {'1. open': '67.3000',
#    '2. high': '68.0000',
#    '3. low': '67.0400',
#    '4. close': '67.4300',
#    '5. adjusted close': '39.4557',
#    '6. volume': '28398400',
#    '7. dividend amount': '0.0000'},
#   '2005-05-20': {'1. open': '67.1100',
#    '2. high': '68.0800',
#    '3. low': '67.0700',
#    '4. close': '67.2000',
#    '5. adjusted close': '39.3211',
#    '6. volume': '32058500',
#    '7. dividend amount': '0.0000'},
#   '2005-05-13': {'1. open': '68.1000',
#    '2. high': '68.2900',
#    '3. low': '66.7550',
#    '4. close': '67.1000',
#    '5. adjusted close': '39.2626',
#    '6. volume': '29406400',
#    '7. dividend amount': '0.3300'},
#   '2005-05-06': {'1. open': '68.6800',
#    '2. high': '68.8700',
#    '3. low': '67.6500',
#    '4. close': '68.2100',
#    '5. adjusted close': '39.7168',
#    '6. volume': '29527800',
#    '7. dividend amount': '0.0000'},
#   '2005-04-29': {'1. open': '69.0000',
#    '2. high': '69.5000',
#    '3. low': '67.6200',
#    '4. close': '68.6300',
#    '5. adjusted close': '39.9614',
#    '6. volume': '30762000',
#    '7. dividend amount': '0.0000'},
#   '2005-04-22': {'1. open': '69.3000',
#    '2. high': '69.9500',
#    '3. low': '67.8300',
#    '4. close': '68.4900',
#    '5. adjusted close': '39.8798',
#    '6. volume': '41109100',
#    '7. dividend amount': '0.0000'},
#   '2005-04-15': {'1. open': '68.8000',
#    '2. high': '69.9900',
#    '3. low': '67.8500',
#    '4. close': '69.4000',
#    '5. adjusted close': '40.4097',
#    '6. volume': '42423600',
#    '7. dividend amount': '0.0000'},
#   '2005-04-08': {'1. open': '66.9500',
#    '2. high': '69.4800',
#    '3. low': '66.8500',
#    '4. close': '68.6400',
#    '5. adjusted close': '39.9672',
#    '6. volume': '33287100',
#    '7. dividend amount': '0.0000'},
#   '2005-04-01': {'1. open': '68.2300',
#    '2. high': '68.5000',
#    '3. low': '66.6500',
#    '4. close': '66.8500',
#    '5. adjusted close': '38.9249',
#    '6. volume': '44693600',
#    '7. dividend amount': '0.0000'},
#   '2005-03-24': {'1. open': '67.2500',
#    '2. high': '68.5200',
#    '3. low': '66.6500',
#    '4. close': '68.0900',
#    '5. adjusted close': '39.6469',
#    '6. volume': '28693000',
#    '7. dividend amount': '0.0000'},
#   '2005-03-18': {'1. open': '67.5900',
#    '2. high': '67.8500',
#    '3. low': '66.6600',
#    '4. close': '67.2500',
#    '5. adjusted close': '39.1578',
#    '6. volume': '31058200',
#    '7. dividend amount': '0.0000'},
#   '2005-03-11': {'1. open': '67.9000',
#    '2. high': '68.6800',
#    '3. low': '67.4900',
#    '4. close': '67.6000',
#    '5. adjusted close': '39.3616',
#    '6. volume': '35150800',
#    '7. dividend amount': '0.0000'},
#   '2005-03-04': {'1. open': '66.0700',
#    '2. high': '67.7500',
#    '3. low': '65.6000',
#    '4. close': '67.7400',
#    '5. adjusted close': '39.4431',
#    '6. volume': '36390900',
#    '7. dividend amount': '0.0000'},
#   ...}}

# %% [markdown]
# ### Saving Raw Output

# %%
import os
# Save the weekly closing prices to a file
directory = f"./Weekly-Closing-Prices/{stockName}_Pricing/"
if not os.path.exists(directory):
    os.makedirs(directory)

#  Save the data to a JSON file
with open(f"./Weekly-Closing-Prices/{stockName}_Pricing/raw_{stockName}_data.json", 'w') as file:
    json.dump(data, file)

# %% [markdown]
# ### Filtering for closing prices

# %%
weekly_closes = {date: week_info["5. adjusted close"] for date, week_info in data["Weekly Adjusted Time Series"].items()}

# %% [markdown]
# ### Saving close price data

# %%
# Save the weekly closing prices to a file
with open(f"./Weekly-Closing-Prices/{stockName}_Pricing/{stockName}_weekly_close.json", 'w') as file:
    json.dump(weekly_closes, file)

# %% [markdown]
# ### Vol + Close Price

# %%
df = pd.DataFrame({
    'Date': data["Weekly Adjusted Time Series"].keys(),
    'Adjusted_Close': [info["5. adjusted close"] for info in data["Weekly Adjusted Time Series"].values()],
    'Volume': [info["6. volume"] for info in data["Weekly Adjusted Time Series"].values()]
})

df
# Out:
#             Date Adjusted_Close    Volume
# 0     2024-04-22       149.1200  10118694
# 1     2024-04-19       147.9100  50293639
# 2     2024-04-12       147.5200  34293828
# 3     2024-04-05       152.3900  31591782
# 4     2024-03-28       158.1900  29005302
# ...          ...            ...       ...
# 1272  1999-12-10        25.3690  21064900
# 1273  1999-12-03        26.1405  15689000
# 1274  1999-11-26        27.7398   6222500
# 1275  1999-11-19        28.2774  10273400
# 1276  1999-11-12        27.9011   9922400
#
# [1277 rows x 3 columns]

# %%
# Save the weekly closing prices to a file
# Save the DataFrame to a JSON file
df.to_json(f'Weekly-Closing-Prices/{stockName}_Pricing/{stockName}_weekly_close_vol.json', orient='records', date_format='iso')
